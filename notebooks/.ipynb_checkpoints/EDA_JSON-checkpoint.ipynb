# %%
# %cd ~/Documents/dofus_scrap/

import os
import json
from pprint import pprint


def load_json(path: str) -> dict:
    with open(path, 'r') as json_file:
        data = json.load(json_file)
    return data


json_paths = [
    os.path.join('data', f)
    for f in os.listdir('data')
    if f.endswith('.json')
]

data = {
    path.split('/')[1].split('.')[0]: load_json(path)
    for path in json_paths
}
# Out:
# /home/pierrotlc/Documents/dofus_scrap

# %% [markdown]
# ## Primary keys

# %%
def get_primary_keys(data: dict, keep_all: bool) -> dict[str, set[str]]:
    primary_keys = dict()
    for category, items in data.items():
        primary_keys[category] = set()
        for i in items:
            if keep_all or primary_keys[category] == set():
                primary_keys[category] |= set(i.keys())
            elif 'erreur 404' not in i.keys():
                primary_keys[category] &= set(i.keys())

    return primary_keys


def get_all_unique_primary_keys_set(data: dict) -> dict[str, set[frozenset[str]]]:
    primary_keys = dict()
    for category, items in data.items():
        primary_keys[category] = set()
        for i in items:
            primary_keys[category].add(frozenset(i.keys()))

    return primary_keys


primary_keys = get_primary_keys(data, keep_all=True)

# %% [markdown]
# Primary keys for each category.

# %%
for category, keys in primary_keys.items():
    print(f'For category: {category}')
    for k in sorted(keys):
        print(f' - {k}')
    print('')
# Out:
# For category: ressources
#  - Type
#  - conditions
#  - description
#  - effets
#  - erreur 404
#  - illustration_url
#  - niveau
#  - nom
#  - recette
#  - url
#
# For category: consommables
#  - Type
#  - conditions
#  - description
#  - effets
#  - erreur 404
#  - illustration_url
#  - niveau
#  - nom
#  - recette
#  - url
#
# For category: équipements
#  - Type
#  - conditions
#  - description
#  - effets
#  - erreur 404
#  - illustration_url
#  - niveau
#  - nom
#  - recette
#  - url
#
# For category: armes
#  - Type
#  - caractéristiques
#  - conditions
#  - description
#  - dégâts
#  - effets
#  - erreur 404
#  - illustration_url
#  - niveau
#  - nom
#  - recette
#  - url
#
# For category: objets d'apparat
#  - Type
#  - conditions
#  - description
#  - erreur 404
#  - illustration_url
#  - niveau
#  - nom
#  - recette
#  - url
#
# For category: bestiaire
#  - Race
#  - butins
#  - butins conditionnés
#  - caractéristiques
#  - de la même famille
#  - illustration_url
#  - niveau
#  - nom
#  - résistances
#  - url
#
# For category: compagnons
#  - Type
#  - description
#  - illustration_url
#  - nom
#  - url
#
# For category: familiers
#  - Type
#  - conditions
#  - description
#  - effets évolutifs
#  - erreur 404
#  - illustration_url
#  - niveau
#  - nom
#  - url
#
# For category: montures
#  - Type
#  - caractéristiques
#  - effets
#  - illustration_url
#  - issu du croisement
#  - nom
#  - url
#
# For category: harnachements
#  - Type
#  - conditions
#  - description
#  - erreur 404
#  - illustration_url
#  - niveau
#  - nom
#  - url
#
# For category: panoplies
#  - Type
#  - bonus de la panoplie
#  - composition
#  - illustration_url
#  - niveau
#  - nom
#  - url
#
# For category: idoles
#  - Type
#  - bonus
#  - description
#  - illustration_url
#  - niveau
#  - nom
#  - recette
#  - sorts
#  - url

# %% [markdown]
# Primary keys common for all categories.

# %%
common = set()
for pk in primary_keys.values():
    common |= pk
    
for pk in primary_keys.values():
    common &= pk

print('Common primary keys:')
for k in common:
    print(f'- {k}')
    

cats = set(primary_keys.keys())
cats.remove('bestiaire')
common = set()
for cat, pk in primary_keys.items():
    if cat in cats:
        common |= pk
    
for cat, pk in primary_keys.items():
    if cat in cats:
        common &= pk

print('Common without bestiaire:')
for k in common:
    print(f'- {k}')
# Out:
# Common primary keys:
# - nom
# - illustration_url
# - url
# Common without bestiaire:
# - illustration_url
# - nom
# - Type
# - url

# %% [markdown]
# Now we select the keys that are present in all items of each category

# %%
primary_keys = get_all_unique_primary_keys_set(data)
for cat, keys in primary_keys.items():
    print(f'For {cat}:')
    for k in keys:
        print(list(sorted(k)))
    print()
# Out:
# For ressources:
# ['Type', 'description', 'effets', 'illustration_url', 'niveau', 'nom', 'recette', 'url']
# ['Type', 'conditions', 'description', 'illustration_url', 'niveau', 'nom', 'recette', 'url']
# ['Type', 'conditions', 'description', 'effets', 'illustration_url', 'niveau', 'nom', 'recette', 'url']
# ['Type', 'description', 'illustration_url', 'niveau', 'nom', 'recette', 'url']
# ['erreur 404', 'url']
# ['Type', 'description', 'illustration_url', 'niveau', 'nom', 'url']
# ['Type', 'description', 'effets', 'illustration_url', 'niveau', 'nom', 'url']
#
# For consommables:
# ['Type', 'description', 'effets', 'illustration_url', 'niveau', 'nom', 'recette', 'url']
# ['Type', 'conditions', 'description', 'illustration_url', 'niveau', 'nom', 'recette', 'url']
# ['Type', 'description', 'illustration_url', 'niveau', 'nom', 'recette', 'url']
# ['erreur 404', 'url']
# ['Type', 'conditions', 'description', 'effets', 'illustration_url', 'niveau', 'nom', 'recette', 'url']
# ['Type', 'conditions', 'description', 'illustration_url', 'niveau', 'nom', 'url']
# ['Type', 'description', 'illustration_url', 'niveau', 'nom', 'url']
# ['Type', 'description', 'effets', 'illustration_url', 'niveau', 'nom', 'url']
# ['Type', 'conditions', 'description', 'effets', 'illustration_url', 'niveau', 'nom', 'url']
#
# For équipements:
# ['Type', 'description', 'effets', 'illustration_url', 'niveau', 'nom', 'recette', 'url']
# ['Type', 'conditions', 'description', 'illustration_url', 'niveau', 'nom', 'recette', 'url']
# ['Type', 'conditions', 'description', 'effets', 'illustration_url', 'niveau', 'nom', 'recette', 'url']
# ['Type', 'description', 'illustration_url', 'niveau', 'nom', 'recette', 'url']
# ['erreur 404', 'url']
# ['Type', 'conditions', 'description', 'illustration_url', 'niveau', 'nom', 'url']
# ['Type', 'description', 'illustration_url', 'niveau', 'nom', 'url']
# ['Type', 'description', 'effets', 'illustration_url', 'niveau', 'nom', 'url']
# ['Type', 'conditions', 'description', 'effets', 'illustration_url', 'niveau', 'nom', 'url']
#
# For armes:
# ['Type', 'caractéristiques', 'conditions', 'description', 'dégâts', 'effets', 'illustration_url', 'niveau', 'nom', 'recette', 'url']
# ['Type', 'caractéristiques', 'description', 'dégâts', 'effets', 'illustration_url', 'niveau', 'nom', 'recette', 'url']
# ['Type', 'caractéristiques', 'description', 'effets', 'illustration_url', 'niveau', 'nom', 'url']
# ['Type', 'caractéristiques', 'description', 'illustration_url', 'niveau', 'nom', 'url']
# ['Type', 'caractéristiques', 'description', 'dégâts', 'effets', 'illustration_url', 'niveau', 'nom', 'url']
# ['erreur 404', 'url']
# ['Type', 'caractéristiques', 'conditions', 'description', 'effets', 'illustration_url', 'niveau', 'nom', 'url']
# ['Type', 'caractéristiques', 'conditions', 'description', 'dégâts', 'effets', 'illustration_url', 'niveau', 'nom', 'url']
#
# For objets d'apparat:
# ['Type', 'conditions', 'description', 'illustration_url', 'niveau', 'nom', 'recette', 'url']
# ['Type', 'description', 'illustration_url', 'niveau', 'nom', 'recette', 'url']
# ['erreur 404', 'url']
# ['Type', 'conditions', 'description', 'illustration_url', 'niveau', 'nom', 'url']
# ['Type', 'description', 'illustration_url', 'niveau', 'nom', 'url']
#
# For bestiaire:
# ['Race', 'butins', 'caractéristiques', 'de la même famille', 'illustration_url', 'niveau', 'nom', 'résistances', 'url']
# ['Race', 'butins', 'butins conditionnés', 'caractéristiques', 'illustration_url', 'niveau', 'nom', 'résistances', 'url']
# ['Race', 'caractéristiques', 'de la même famille', 'illustration_url', 'niveau', 'nom', 'résistances', 'url']
# ['Race', 'caractéristiques', 'illustration_url', 'niveau', 'nom', 'résistances', 'url']
# ['Race', 'butins', 'butins conditionnés', 'caractéristiques', 'de la même famille', 'illustration_url', 'niveau', 'nom', 'résistances', 'url']
#
# For compagnons:
# ['Type', 'description', 'illustration_url', 'nom', 'url']
#
# For familiers:
# ['Type', 'description', 'effets évolutifs', 'illustration_url', 'niveau', 'nom', 'url']
# ['Type', 'conditions', 'description', 'effets évolutifs', 'illustration_url', 'niveau', 'nom', 'url']
# ['erreur 404', 'url']
# ['Type', 'conditions', 'description', 'illustration_url', 'niveau', 'nom', 'url']
# ['Type', 'description', 'illustration_url', 'niveau', 'nom', 'url']
#
# For montures:
# ['Type', 'caractéristiques', 'illustration_url', 'nom', 'url']
# ['Type', 'caractéristiques', 'effets', 'illustration_url', 'nom', 'url']
# ['Type', 'caractéristiques', 'effets', 'illustration_url', 'issu du croisement', 'nom', 'url']
#
# For harnachements:
# ['erreur 404', 'url']
# ['Type', 'conditions', 'description', 'illustration_url', 'niveau', 'nom', 'url']
# ['Type', 'description', 'illustration_url', 'niveau', 'nom', 'url']
#
# For panoplies:
# ['Type', 'bonus de la panoplie', 'composition', 'illustration_url', 'niveau', 'nom', 'url']
#
# For idoles:
# ['Type', 'bonus', 'description', 'illustration_url', 'niveau', 'nom', 'url']
# ['Type', 'bonus', 'description', 'illustration_url', 'niveau', 'nom', 'recette', 'sorts', 'url']
# ['Type', 'bonus', 'description', 'illustration_url', 'niveau', 'nom', 'sorts', 'url']

# %%
key = 'conditions'
for d in data.values():
    for item in d:
        if key in item:
            print(item[key])
# Out:
# {'null': [{'special': "Quête 'Rencontres d’un soir' achevée"}]}
# {'ou': [{'special': 'Forgemage'}, {'special': 'Sculptemage'}]}
# {'ou': [{'special': 'Forgemage'}, {'special': 'Sculptemage'}]}
# {'ou': [{'special': 'Forgemage'}, {'special': 'Sculptemage'}]}
# {'ou': [{'special': 'Forgemage'}, {'special': 'Sculptemage'}]}
# {'ou': [{'special': 'Forgemage'}, {'special': 'Sculptemage'}]}
# {'ou': [{'special': 'Forgemage'}, {'special': 'Sculptemage'}]}
# {'ou': [{'special': 'Forgemage'}, {'special': 'Sculptemage'}]}
# {'ou': [{'special': 'Forgemage'}, {'special': 'Sculptemage'}]}
# {'ou': [{'special': 'Forgemage'}, {'special': 'Sculptemage'}]}
# {'ou': [{'special': 'Forgemage'}, {'special': 'Sculptemage'}]}
# {'ou': [{'special': 'Forgemage'}, {'special': 'Sculptemage'}]}
# {'ou': [{'special': 'Forgemage'}, {'special': 'Sculptemage'}]}
# {'ou': [{'special': 'Forgemage'}, {'special': 'Sculptemage'}]}
# {'ou': [{'special': 'Forgemage'}, {'special': 'Sculptemage'}]}
# {'ou': [{'special': 'Forgemage'}, {'special': 'Sculptemage'}]}
# {'ou': [{'special': 'Forgemage'}, {'special': 'Sculptemage'}]}
# {'ou': [{'special': 'Forgemage'}, {'special': 'Sculptemage'}]}
# {'ou': [{'special': 'Forgemage'}, {'special': 'Sculptemage'}]}
# {'ou': [{'special': 'Forgemage'}, {'special': 'Sculptemage'}]}
# {'ou': [{'special': 'Forgemage'}, {'special': 'Sculptemage'}]}
# {'ou': [{'special': 'Forgemage'}, {'special': 'Sculptemage'}]}
# {'ou': [{'special': 'Forgemage'}, {'special': 'Sculptemage'}]}
# {'ou': [{'special': 'Forgemage'}, {'special': 'Sculptemage'}]}
# {'ou': [{'special': 'Forgemage'}, {'special': 'Sculptemage'}]}
# {'null': [{'special': '< 100'}]}
# {'null': [{'<': ['Force de base', 100]}]}
# {'null': [{'special': '< 100'}]}
# {'null': [{'special': '< 100'}]}
# {'null': [{'special': '< 100'}]}
# {'null': [{'special': '< 100'}]}
# {'et': [{'>': ['Niveau', 49]}, {'special': 'Posséder le droit de guilde : Meneur, Bannir'}]}
# {'null': [{'special': '< 90'}]}
# {'null': [{'special': '< 95'}]}
# {'null': [{'<': ['Force de base', 95]}]}
# {'null': [{'<': ['Force de base', 90]}]}
# {'null': [{'special': '< 90'}]}
# {'null': [{'special': '< 90'}]}
# {'null': [{'special': '< 90'}]}
# {'null': [{'special': '< 90'}]}
# {'null': [{'<': ['Force de base', 85]}]}
# {'null': [{'special': '< 80'}]}
# {'null': [{'special': '< 85'}]}
# {'null': [{'special': '< 80'}]}
# {'null': [{'<': ['Force de base', 80]}]}
# {'null': [{'special': '< 80'}]}
# {'null': [{'special': '< 80'}]}
# {'null': [{'special': '< 80'}]}
# {'null': [{'special': '< 70'}]}
# {'null': [{'special': '< 75'}]}
# {'null': [{'<': ['Force de base', 75]}]}
# {'null': [{'<': ['Force de base', 70]}]}
# {'et': [{'special': 'Zone : Île de Grobe'}, {'special': "Ne pas posséder l'objet 'Je vois des gens qui sont morts'"}, {'special': 'Etre abonné'}, {'special': "Quête 'Le réveil de Pandala ' achevée"}]}
# {'null': [{'special': '< 70'}]}
# {'null': [{'special': '< 70'}]}
# {'null': [{'special': '< 70'}]}
# {'null': [{'special': '< 70'}]}
# {'null': [{'<': ['Force de base', 65]}]}
# {'null': [{'special': '< 60'}]}
# {'null': [{'special': '< 65'}]}
# {'null': [{'special': '< 60'}]}
# {'null': [{'special': '< 60'}]}
# {'null': [{'<': ['Force de base', 60]}]}
# {'null': [{'special': '< 60'}]}
# {'null': [{'special': '< 60'}]}
# {'et': [{'special': "Quête 'Taures"}, {'special': "détours' achevée ou"}, {'et': [{'special': "Quête 'Taures"}, {'special': "détours' en cours"}]}]}
# {'null': [{'special': '< 55'}]}
# {'null': [{'<': ['Force de base', 55]}]}
# {'null': [{'special': '< 50'}]}
# {'null': [{'special': '< 50'}]}
# {'et': [{'>': ['Niveau', 99]}, {'ou': [{'special': "Sous-zone : Berceau d'Alma"}, {'special': "Sous-zone : Larmes d'Ouronigride"}]}]}
# {'null': [{'special': "Avoir fini le succès 'Miausolée du Pounicheur'"}]}
# {'null': [{'special': "Avoir fini le succès 'Fabrique de Malléfisk'"}]}
# {'null': [{'special': '< 100'}]}
# {'et': [{'special': "Quête 'Un gros cube, un p'ti cube' disponible"}, {'special': "Quête 'Un gros cube, un p'ti cube' en cours"}]}
# {'null': [{'special': '< 50'}]}
# {'null': [{'special': '< 50'}]}
# {'null': [{'special': "Avoir fini le succès 'Mégalithe de Fraktale'"}]}
# {'null': [{'special': '< 50'}]}
# {'null': [{'special': '< 50'}]}
# {'null': [{'<': ['Force de base', 50]}]}
# {'null': [{'special': '< 45'}]}
# {'null': [{'special': '< 40'}]}
# {'null': [{'<': ['Force de base', 45]}]}
# {'null': [{'special': '< 40'}]}
# {'null': [{'special': '< 40'}]}
# {'null': [{'special': '< 40'}]}
# {'null': [{'<': ['Force de base', 40]}]}
# {'null': [{'special': '< 40'}]}
# {'null': [{'special': '< 30'}]}
# {'null': [{'<': ['Force de base', 35]}]}
# {'null': [{'special': '< 35'}]}
# {'null': [{'special': "Ne pas posséder l'objet 'Transformation en Crapaud-mufle'"}]}
# {'null': [{'special': '< 30'}]}
# {'null': [{'<': ['Force de base', 30]}]}
# {'null': [{'special': '< 30'}]}
# {'null': [{'special': '< 30'}]}
# {'et': [{'special': 'Etre abonné'}, {'special': 'Zone différente de : Incarnam'}]}
# {'null': [{'special': '< 30'}]}
# {'null': [{'special': 'Ne pas être en zone restreinte'}]}
# {'null': [{'special': '< 20'}]}
# {'et': [{'>': ['Niveau', 49]}, {'special': "Posséder l'objet 'Certificat de Croque-mort'"}]}
# {'null': [{'special': 'Etre abonné'}]}
# {'et': [{'>': ['Niveau', 49]}, {'special': "Posséder l'objet 'Certificat de Guérisseur'"}]}
# {'null': [{'<': ['Force de base', 25]}]}
# {'null': [{'ou': [{'special': "Sous-zone : Forêt d'Amakna"}, {'special': 'Sous-zone : Bord de la forêt maléfique'}, {'special': 'Sous-zone : Bois des Arak-haï'}, {'special': 'Sous-zone : Orée de la forêt des Abraknydes'}, {'special': 'Sous-zone : Plaine des Scarafeuilles'}, {'special': 'Sous-zone : Forêt Sombre'}]}]}
# {'null': [{'special': '< 20'}]}
# {'null': [{'special': '< 20'}]}
# {'ou': [{'special': "Quête 'Un pouvoir mérydique' en cours"}, {'special': "Quête 'Un pouvoir mérydique' achevée"}]}
# {'et': [{'special': "Quête 'La raison du plus fort' achevée"}, {'>': ['Niveau', 39]}]}
# {'null': [{'special': '< 20'}]}
# {'et': [{'special': "Quête 'La magicienne des marécages' achevée"}, {'>': ['Niveau', 39]}]}
# {'null': [{'special': '< 20'}]}
# {'null': [{'<': ['Force de base', 20]}]}
# {'et': [{'special': 'Etre abonné'}, {'special': 'Zone différente de : Incarnam'}]}
# {'null': [{'<': ['Force de base', 15]}]}
# {'null': [{'special': '< 10'}]}
# {'et': [{'special': "Quête 'Shushu"}, {'special': "Lulu' achevée"}, {'special': 'Zone différente de : Incarnam'}]}
# {'null': [{'special': '< 10'}]}
# {'null': [{'<': ['Force de base', 10]}]}
# {'null': [{'special': '< 10'}]}
# {'null': [{'special': '< 10'}]}
# {'ou': [{'special': 'Alignement différent de 3'}, {'null': [{'special': 'Alignement 2'}]}]}
# {'ou': [{'special': 'Alignement différent de 3'}, {'null': [{'special': 'Alignement 1'}]}]}
# {'null': [{'special': '< 10'}]}
# {'null': [{'special': 'Zone différente de : Incarnam'}]}
# {'null': [{'special': 'Zone différente de : Incarnam'}]}
# {'null': [{'special': 'Zone différente de : Incarnam'}]}
# {'null': [{'special': 'Zone différente de : Incarnam'}]}
# {'null': [{'special': 'Zone différente de : Incarnam'}]}
# {'null': [{'special': 'Zone différente de : Incarnam'}]}
# {'null': [{'special': 'Zone différente de : Incarnam'}]}
# {'null': [{'special': 'Zone différente de : Incarnam'}]}
# {'null': [{'special': 'Zone différente de : Incarnam'}]}
# {'null': [{'special': 'Zone différente de : Incarnam'}]}
# {'null': [{'special': 'Zone différente de : Incarnam'}]}
# {'null': [{'special': 'Zone différente de : Incarnam'}]}
# {'null': [{'special': 'Zone différente de : Incarnam'}]}
# {'null': [{'special': 'Zone différente de : Incarnam'}]}
# {'null': [{'special': 'Zone différente de : Incarnam'}]}
# {'null': [{'special': 'Zone différente de : Incarnam'}]}
# {'null': [{'special': '< 5'}]}
# {'null': [{'special': '< 5'}]}
# {'null': [{'<': ['Force de base', 5]}]}
# {'null': [{'>': ['Niveau', 50]}]}
# {'null': [{'>': ['Niveau', 50]}]}
# {'null': [{'>': ['Niveau', 50]}]}
# {'null': [{'special': '< 5'}]}
# {'null': [{'special': '< 5'}]}
# {'null': [{'special': '< 5'}]}
# {'null': [{'special': 'Ne pas être en zone restreinte'}]}
# {'null': [{'special': 'Ne pas être en zone restreinte'}]}
# {'null': [{'special': 'Ne pas être en zone restreinte'}]}
# {'null': [{'special': 'Ne pas être en zone restreinte'}]}
# {'null': [{'special': 'Ne pas être en zone restreinte'}]}
# {'null': [{'special': 'Ne pas être en zone restreinte'}]}
# {'null': [{'special': 'Ne pas être en zone restreinte'}]}
# {'null': [{'special': 'Ne pas être en zone restreinte'}]}
# {'null': [{'special': 'Ne pas être en zone restreinte'}]}
# {'null': [{'special': 'Ne pas être en zone restreinte'}]}
# {'null': [{'special': 'Ne pas être en zone restreinte'}]}
# {'null': [{'special': 'Ne pas être en zone restreinte'}]}
# {'null': [{'special': 'Ne pas être en zone restreinte'}]}
# {'null': [{'special': 'Ne pas être en zone restreinte'}]}
# {'null': [{'special': 'Ne pas être en zone restreinte'}]}
# {'null': [{'special': 'Ne pas être en zone restreinte'}]}
# {'null': [{'special': 'Zone différente de : Incarnam'}]}
# {'null': [{'<': ['Force de base', 25]}]}
# {'null': [{'special': '< 25'}]}
# {'null': [{'<': ['Force de base', 50]}]}
# {'null': [{'<': ['Force de base', 100]}]}
# {'null': [{'special': '< 100'}]}
# {'null': [{'special': '< 50'}]}
# {'null': [{'special': '< 80'}]}
# {'null': [{'special': '< 100'}]}
# {'null': [{'special': "Ne pas connaître l'attitude 'Lâcher les gaz'"}]}
# {'null': [{'special': "Ne pas posséder l'objet 'Goût de Bonbon Rouge Surpuissant'"}]}
# {'null': [{'special': "Ne pas posséder l'objet 'Goût de Shigekax Orange'"}]}
# {'null': [{'special': "Ne pas posséder l'objet 'Goût de Shigekax Reinette'"}]}
# {'null': [{'special': "Ne pas posséder l'objet 'Goût de Shigekax Mirabelle'"}]}
# {'null': [{'ou': [{'special': 'Sous-zone : Montagne des Craqueleurs'}, {'special': "Sous-zone : Carrière d'Astrub"}, {'special': 'Sous-zone : Montagne basse des Craqueleurs'}]}]}
# {'null': [{'special': "Ne pas posséder l'objet 'Goût de Menthe du Prospecteur'"}]}
# {'null': [{'special': "Posséder l'objet 'Malédiction du Ballotin'"}]}
# {'null': [{'special': "Ne pas connaître l'attitude 'Super-héros'"}]}
# {'null': [{'special': "Ne pas connaître l'attitude 'Refuser'"}]}
# {'null': [{'special': "Ne pas connaître l'attitude 'Offrir un cadeau'"}]}
# {'null': [{'special': "Ne pas connaître l'attitude 'Brandir son arme'"}]}
# {'null': [{'special': "Ne pas connaître l'attitude 'Croiser les bras'"}]}
# {'null': [{'special': "Ne pas connaître l'attitude 'Baisser le pouce'"}]}
# {'null': [{'special': "Ne pas connaître l'attitude 'Manolias'"}]}
# {'null': [{'special': "Ne pas connaître l'attitude 'Avoir froid'"}]}
# {'null': [{'special': "Ne pas connaître l'attitude 'Avoir chaud'"}]}
# {'null': [{'special': "Ne pas connaître l'attitude 'Attirer l'attention'"}]}
# {'null': [{'special': "Ne pas connaître l'attitude 'Se frotter les mains'"}]}
# {'null': [{'special': "Ne pas posséder l'objet 'Goût de Sukette à la Fraise'"}]}
# {'null': [{'special': "Ne pas posséder l'objet 'Goût de Sukette au Citron'"}]}
# {'null': [{'special': "Ne pas posséder l'objet 'Effet Zaï Hallucinogène'"}]}
# {'null': [{'special': "Ne pas posséder l'objet 'Effet du Prospecteur'"}]}
# {'null': [{'special': "Ne pas posséder l'objet 'Effet du Formateur'"}]}
# {'null': [{'special': "Ne pas connaître l'attitude 'Boxer'"}]}
# {'null': [{'special': "Ne pas connaître l'attitude 'Siffler'"}]}
# {'null': [{'special': "Ne pas connaître l'attitude 'Garde-à-vous'"}]}
# {'null': [{'special': "Ne pas connaître l'attitude 'Balistique'"}]}
# {'null': [{'special': "Ne pas connaître l'attitude 'Pêcheur'"}]}
# {'null': [{'special': 'Ne possède pas le pack de smiley : "Halouine"'}]}
# {'null': [{'special': "Ne pas connaître l'attitude 'Élémentaire'"}]}
# {'null': [{'special': "Ne pas connaître l'attitude 'Animal'"}]}
# {'null': [{'special': "Ne pas connaître l'attitude 'Indestructible'"}]}
# {'null': [{'special': "Ne pas connaître l'attitude 'Expérimenter'"}]}
# {'null': [{'special': "Ne pas connaître l'attitude 'Enragé'"}]}
# {'null': [{'special': "Ne pas connaître l'attitude 'Supporter Batailleurs Glorieux S2'"}]}
# {'null': [{'special': "Ne pas connaître l'attitude 'Supporter Millenium S3'"}]}
# {'null': [{'special': "Ne pas connaître l'attitude 'Supporter Out of Control S3'"}]}
# {'null': [{'special': "Ne pas posséder l'objet 'Goût de Koukawa Fraise'"}]}
# {'null': [{'special': "Ne pas posséder l'objet 'Bénédiction de la Prêtresse des Douze'"}]}
# {'null': [{'special': "Ne pas posséder l'objet 'Goût de Perlequin Coco'"}]}
# {'null': [{'special': "Ne pas posséder l'objet 'Goût de Perlequin Griotte'"}]}
# {'null': [{'special': "Ne pas posséder l'objet 'Goût de Perlequin Indigo'"}]}
# {'null': [{'special': "Ne pas posséder l'objet 'Goût de Perlequin Reinette'"}]}
# {'null': [{'special': "Ne pas connaître l'attitude 'Danse du trool'"}]}
# {'null': [{'special': "Ne pas connaître l'attitude 'Guitare électromagique'"}]}
# {'null': [{'special': "Ne pas connaître l'attitude 'Aura Musicale'"}]}
# {'null': [{'special': "Ne pas posséder l'objet 'Goût de Perlequin Ananas'"}]}
# {'null': [{'special': "Ne pas posséder l'objet 'Super bonbon du Prospecteur'"}]}
# {'null': [{'special': "Ne pas posséder l'objet 'Super bonbon du Sage'"}]}
# {'null': [{'special': "Ne pas connaître l'attitude 'Anniversaire'"}]}
# {'null': [{'special': "Ne pas connaître l'attitude 'Sorti du chapeau'"}]}
# {'null': [{'special': "Ne pas posséder l'objet 'Cinquième saveur'"}]}
# {'null': [{'special': "Ne pas connaître l'attitude 'Fête du Slip'"}]}
# {'null': [{'special': "Ne pas connaître l'attitude 'Supporter Emperor'"}]}
# {'null': [{'special': "Ne pas connaître l'attitude 'Souffle dégivrant de Silouate'"}]}
# {'null': [{'special': "Ne pas connaître l'attitude 'Plante grimpante de Rosal'"}]}
# {'null': [{'special': "Ne pas posséder l'objet 'Coquetel ékrochai'"}]}
# {'null': [{'special': "Ne pas posséder l'objet 'Coquetel éacha'"}]}
# {'null': [{'special': "Ne pas posséder l'objet 'Coquetel éthon'"}]}
# {'null': [{'special': "Ne pas posséder l'objet 'Coquetel aiskop'"}]}
# {'null': [{'<': ['Force de base', 80]}]}
# {'null': [{'special': '< 100'}]}
# {'null': [{'special': "Ne pas posséder l'objet 'Goût de Shigekax Caramel'"}]}
# {'null': [{'special': "Ne pas posséder l'objet 'Goût de Shigekax Chocolat'"}]}
# {'null': [{'special': "Ne pas posséder l'objet 'Goût de Shigekax Melon'"}]}
# {'null': [{'special': "Ne pas posséder l'objet 'Goût de Shigekax Griotte'"}]}
# {'null': [{'special': "Ne pas posséder l'objet 'Goût de Shigekax Acidulé'"}]}
# {'null': [{'special': "Posséder l'objet 'Pichon d'Aperirel'"}]}
# {'null': [{'special': "Ne pas connaître l'attitude 'S'agenouiller'"}]}
# {'ou': [{'special': "Ne pas connaître l'attitude 'Pierre'"}, {'special': "Ne pas connaître l'attitude 'Feuille'"}, {'special': "Ne pas connaître l'attitude 'Ciseaux'"}]}
# {'null': [{'special': "Ne pas connaître l'attitude 'Manolias'"}]}
# {'null': [{'special': "Ne pas connaître l'attitude 'Mains sur les hanches'"}]}
# {'null': [{'special': "Ne pas connaître l'attitude 'Applaudir'"}]}
# {'null': [{'special': "Ne pas connaître l'attitude 'Se prosterner'"}]}
# {'null': [{'special': "Ne pas connaître l'attitude 'Gonfler ses muscles'"}]}
# {'null': [{'special': "Ne pas posséder l'objet 'Goût de Sukette à la Pomme'"}]}
# {'null': [{'special': "Ne pas posséder l'objet 'Effet Zaï Planant'"}]}
# {'null': [{'special': "Ne pas connaître l'attitude 'Agiter le drapeau blanc'"}]}
# {'null': [{'special': "Ne pas connaître l'attitude 'Supplier'"}]}
# {'null': [{'special': "Ne pas connaître l'attitude 'Chercher un trésor'"}]}
# {'null': [{'special': "Ne pas connaître l'attitude 'Richissime'"}]}
# {'null': [{'special': "Ne pas connaître l'attitude 'Intemporel'"}]}
# {'null': [{'special': "Ne pas connaître l'attitude 'Se boucher les oreilles'"}]}
# {'null': [{'special': "Ne pas connaître l'attitude 'Supporter Free Bowisse S2'"}]}
# {'et': [{'special': "Quête 'La dernière barbe avant la fin du monde' achevée"}, {'special': "Ne pas posséder l'objet 'Gueule de Martegel'"}]}
# {'null': [{'special': "Ne pas connaître l'attitude 'Insectoïde'"}]}
# {'null': [{'special': "Ne pas posséder l'objet 'Carré de Chocolat Noir à 99 %'"}]}
# {'null': [{'special': "Ne pas connaître l'attitude 'Anomalie'"}]}
# {'null': [{'special': "Ne pas posséder l'objet 'Goût de Perlequin Amande'"}]}
# {'null': [{'special': "Ne pas posséder l'objet 'Goût de Perlequin Mirabelle'"}]}
# {'null': [{'special': "Ne pas connaître l'attitude 'Agiter ses cheveux'"}]}
# {'null': [{'special': "Ne pas connaître l'attitude 'Disparition'"}]}
# {'null': [{'special': "Ne pas posséder l'objet 'Rétrécissement'"}]}
# {'null': [{'special': "Ne pas posséder l'objet 'Sixième saveur'"}]}
# {'null': [{'special': "Ne pas connaître l'attitude 'Souffle de Virizeon'"}]}
# {'et': [{'special': "Quête 'L'épopée du moine pèlerin' achevée"}, {'special': "Ne pas posséder l'objet 'Statue de Pouddah'"}]}
# {'et': [{'special': 'Etre abonné'}, {'special': "Quête 'Le réveil de Pandala ' achevée"}]}
# {'null': [{'special': "Ne pas connaître l'attitude 'Guerrier'"}]}
# {'null': [{'special': "Ne pas connaître l'attitude 'Casse-Noisette'"}]}
# {'null': [{'special': "Ne pas connaître l'attitude 'Tonnerre grondant d'Ulgrude'"}]}
# {'null': [{'special': '< 50'}]}
# {'null': [{'special': '< 100'}]}
# {'null': [{'special': '< 80'}]}
# {'null': [{'special': '< 80'}]}
# {'null': [{'special': '< 50'}]}
# {'null': [{'special': "Ne pas posséder l'objet 'Goût de Bonbon Rouge Surpuissant'"}]}
# {'null': [{'special': "Ne pas connaître l'attitude 'Montrer du doigt'"}]}
# {'null': [{'special': "Ne pas posséder l'objet 'Goût de Shigekax Banane'"}]}
# {'null': [{'special': "Ne pas posséder l'objet 'Goût de Shigekax Pomme'"}]}
# {'null': [{'special': "Ne pas posséder l'objet 'Goût de Shigekax Amande'"}]}
# {'null': [{'special': "Ne pas posséder l'objet 'Goût de Shigekax Coco'"}]}
# {'null': [{'special': "Ne pas posséder l'objet 'Goût de Shigekax Prune'"}]}
# {'null': [{'special': 'Sous-zone : Forêt des pins perdus'}]}
# {'null': [{'special': "Ne pas posséder l'objet 'Goût de Menthe du Petit Prospecteur'"}]}
# {'null': [{'special': "Ne pas posséder l'objet 'Goût de Menthe de l'Apprenti'"}]}
# {'null': [{'special': "Ne pas connaître l'attitude 'Se mettre en colère'"}]}
# {'null': [{'special': "Ne pas connaître l'attitude 'S'allonger'"}]}
# {'null': [{'special': "Ne pas connaître l'attitude 'Rire'"}]}
# {'null': [{'special': "Ne pas connaître l'attitude 'Montrer sa peur'"}]}
# {'null': [{'special': "Ne pas connaître l'attitude 'Fleurs'"}]}
# {'null': [{'special': "Ne pas connaître l'attitude 'Lire un livre'"}]}
# {'null': [{'special': "Ne pas connaître l'attitude 'Sautiller'"}]}
# {'null': [{'special': "Ne pas connaître l'attitude 'Jouer du tambour'"}]}
# {'null': [{'special': "Ne pas connaître l'attitude 'Trace'"}]}
# {'null': [{'special': "Ne pas posséder l'objet 'Transformation en Dragoune Dorée'"}]}
# {'null': [{'special': "Ne pas connaître l'attitude 'Lire une carte'"}]}
# {'null': [{'special': "Ne pas connaître l'attitude 'Pied de nez'"}]}
# {'null': [{'special': "Ne pas posséder l'objet 'Goût de Sukette à la Prune'"}]}
# {'null': [{'special': "Ne pas connaître l'attitude 'Encourager'"}]}
# {'null': [{'special': "Ne pas connaître l'attitude 'Écrire'"}]}
# {'null': [{'special': "Posséder le droit d'alliance : Meneur"}]}
# {'null': [{'special': "Ne pas connaître l'attitude 'Ola'"}]}
# {'null': [{'special': "Ne pas connaître l'attitude 'Localiser un portail'"}]}
# {'null': [{'special': "Ne pas connaître l'attitude 'Se frapper le front'"}]}
# {'null': [{'special': "Ne pas connaître l'attitude 'Danser'"}]}
# {'null': [{'special': "Ne pas connaître l'attitude 'Vaporeux'"}]}
# {'null': [{'special': "Ne pas connaître l'attitude 'S'abriter sous un parasol'"}]}
# {'null': [{'special': "Ne pas connaître l'attitude 'Éthylique'"}]}
# {'null': [{'special': "Ne pas connaître l'attitude 'Chanceux'"}]}
# {'null': [{'special': "Ne pas connaître l'attitude 'Sanguinolent'"}]}
# {'null': [{'special': "Ne pas connaître l'attitude 'Bienfaisant'"}]}
# {'null': [{'special': "Ne pas connaître l'attitude 'Psychotique'"}]}
# {'null': [{'special': 'Map : [ -14 : 34 ]'}]}
# {'null': [{'special': "Ne pas connaître l'attitude 'Supporter Out of Control S2'"}]}
# {'null': [{'special': "Ne pas connaître l'attitude 'Dragosaure'"}]}
# {'null': [{'special': "Ne pas posséder l'objet 'Déguisement de Cauchemarakne'"}]}
# {'null': [{'special': "Ne pas posséder l'objet 'Goût de Koukawa Citron'"}]}
# {'null': [{'special': "Ne pas posséder l'objet 'Goût de Koukawabi Pomme Prune'"}]}
# {'null': [{'special': "Ne pas posséder l'objet 'Goût de Koukawabi Prune Citron'"}]}
# {'null': [{'special': "Ne pas posséder l'objet 'Goût de Perlequin Acidulé'"}]}
# {'null': [{'special': "Ne pas posséder l'objet 'Goût de Perlequin Orange'"}]}
# {'null': [{'special': "Ne pas posséder l'objet 'Goût de Perlequin Praline'"}]}
# {'null': [{'special': "Ne pas posséder l'objet 'Goût de Perlequin Prune'"}]}
# {'null': [{'special': "Ne pas connaître l'attitude 'Selfie '"}]}
# {'null': [{'special': "Ne pas connaître l'attitude 'Signe du Shushu'"}]}
# {'null': [{'special': "Ne pas connaître l'attitude 'Crocabulia'"}]}
# {'null': [{'special': "Ne pas posséder l'objet 'Veine de Krikor Nardine'"}]}
# {'null': [{'special': "Ne pas connaître l'attitude 'Rêve'"}]}
# {'null': [{'special': "Ne pas connaître l'attitude 'Ankarton'"}]}
# {'null': [{'special': "Ne pas connaître l'attitude 'Dernier Espoir'"}]}
# {'et': [{'special': 'Etre abonné'}, {'special': "Quête 'Le réveil de Pandala ' achevée"}]}
# {'null': [{'special': "Ne pas connaître l'attitude 'Jackpot'"}]}
# {'null': [{'special': "Ne pas connaître l'attitude 'Animorphose'"}]}
# {'null': [{'special': "Ne pas connaître l'attitude 'Appel de la pluie'"}]}
# {'null': [{'special': "Ne pas connaître l'attitude 'Étendard du Clan Téa'"}]}
# {'null': [{'special': "Ne pas connaître l'attitude 'Faire du ski'"}]}
# {'null': [{'special': "Ne pas connaître l'attitude 'Cycle de Silvosse'"}]}
# {'null': [{'special': "Ne pas connaître l'attitude 'Opulence de Sumens'"}]}
# {'null': [{'special': "Ne pas posséder l'objet 'Coquetel étubbiz'"}]}
# {'null': [{'special': "Ne pas posséder l'objet 'Coquetel écharjabl'"}]}
# {'null': [{'special': '< 80'}]}
# {'null': [{'special': '< 50'}]}
# {'null': [{'special': '< 25'}]}
# {'null': [{'special': '< 100'}]}
# {'null': [{'special': '< 50'}]}
# {'null': [{'special': '< 80'}]}
# {'null': [{'special': "Ne pas posséder l'objet 'Goût de Shigekax Indigo'"}]}
# {'null': [{'special': "Ne pas posséder l'objet 'Goût de Menthe du Petit Apprenti'"}]}
# {'et': [{'ou': [{'special': 'Sous-zone : Port de givre'}, {'special': 'Sous-zone : La Bourgade'}, {'special': 'Sous-zone : Champs de glace'}, {'special': 'Sous-zone : Forêt des pins perdus'}, {'special': 'Sous-zone : Lac gelé'}]}, {'special': 'Map différente de : [ -84 : -49 ]'}]}
# {'et': [{'ou': [{'special': 'Sous-zone : Port de givre'}, {'special': 'Sous-zone : La Bourgade'}, {'special': 'Sous-zone : Champs de glace'}, {'special': 'Sous-zone : Forêt des pins perdus'}, {'special': 'Sous-zone : Lac gelé'}]}, {'special': 'Map différente de : [ -64 : -55 ]'}]}
# {'et': [{'ou': [{'special': 'Sous-zone : Port de givre'}, {'special': 'Sous-zone : La Bourgade'}, {'special': 'Sous-zone : Champs de glace'}, {'special': 'Sous-zone : Forêt des pins perdus'}, {'special': 'Sous-zone : Lac gelé'}]}, {'special': 'Map différente de : [ -76 : -46 ]'}]}
# {'null': [{'special': "Ne pas posséder l'objet 'Esprit de Nowel'"}]}
# {'null': [{'special': "Ne pas connaître l'attitude 'Sylvestre'"}]}
# {'null': [{'special': "Ne pas connaître l'attitude 'Criminel'"}]}
# {'null': [{'special': "Ne pas connaître l'attitude 'Saluer'"}]}
# {'null': [{'special': "Ne pas connaître l'attitude 'Pleurer'"}]}
# {'null': [{'special': "Ne pas connaître l'attitude 'Jouer de la trompette'"}]}
# {'null': [{'special': "Ne pas connaître l'attitude 'Jouer de la flûte'"}]}
# {'null': [{'special': "Ne pas connaître l'attitude 'Faire un signe de la main'"}]}
# {'null': [{'special': "Ne pas connaître l'attitude 'Faire un bisou'"}]}
# {'null': [{'special': "Ne pas connaître l'attitude 'Trace'"}]}
# {'null': [{'special': "Ne pas posséder l'objet 'Transformation en Dragoune Rose'"}]}
# {'null': [{'special': "Ne pas connaître l'attitude 'Piou'"}]}
# {'null': [{'special': "Posséder le droit d'alliance : Meneur"}]}
# {'null': [{'special': "Ne pas connaître l'attitude 'Ouvrir un portail de poche'"}]}
# {'null': [{'special': "Ne pas connaître l'attitude 'Loupe'"}]}
# {'null': [{'special': "Ne pas connaître l'attitude 'Explosif'"}]}
# {'null': [{'special': "Ne pas connaître l'attitude 'Kamarena'"}]}
# {'null': [{'special': 'Ne possède pas le pack de smiley : "Chacha"'}]}
# {'null': [{'special': 'Ne possède pas le pack de smiley : "Chienchien"'}]}
# {'null': [{'special': 'Ne possède pas le pack de smiley : "Bilby"'}]}
# {'null': [{'special': 'Ne possède pas le pack de smiley : "Joris"'}]}
# {'null': [{'special': "Ne pas connaître l'attitude 'Gladiateur'"}]}
# {'null': [{'special': "Ne pas connaître l'attitude 'Supporter GamersOrigin S2'"}]}
# {'null': [{'special': "Ne pas connaître l'attitude 'Supporter GamersOrigin S3'"}]}
# {'null': [{'special': "Ne pas connaître l'attitude 'Supporter OV S3'"}]}
# {'null': [{'special': "Ne pas posséder l'objet 'Déguisement de Dévhorreur'"}]}
# {'null': [{'special': "Ne pas posséder l'objet 'Déguisement de Lanverne'"}]}
# {'null': [{'special': "Ne pas posséder l'objet 'Déguisement de Tofu d'Halouine'"}]}
# {'null': [{'special': "Ne pas connaître l'attitude 'Attitude Dragombre'"}]}
# {'null': [{'special': "Ne pas posséder l'objet 'Goût de Koukawa Prune'"}]}
# {'null': [{'special': "Ne pas posséder l'objet 'Goût de Koukawabi Prune Fraise'"}]}
# {'null': [{'special': "Ne pas posséder l'objet 'Goût de Koukawabi Pomme Citron'"}]}
# {'null': [{'special': "Ne pas connaître l'attitude 'J'ai trop mangé'"}]}
# {'null': [{'special': "Ne pas posséder l'objet 'Garde de Pwâk'"}]}
# {'null': [{'special': "Ne pas posséder l'objet 'Goût de Perlequin Banane'"}]}
# {'null': [{'special': "Ne pas posséder l'objet 'Goût de Perlequin Caramel'"}]}
# {'null': [{'special': "Ne pas posséder l'objet 'Goût de Perlequin Poire'"}]}
# {'null': [{'special': "Ne pas posséder l'objet 'Goût de Perlequin Pastèque'"}]}
# {'null': [{'special': "Ne pas posséder l'objet 'Goût de Perlequin Mangue'"}]}
# {'et': [{'special': 'Etre abonné'}, {'special': "Quête 'Le réveil de Pandala ' achevée"}, {'special': "Ne pas posséder l'objet 'Mort apparente'"}]}
# {'null': [{'special': "Ne pas connaître l'attitude 'Samouraï'"}]}
# {'null': [{'special': "Ne pas connaître l'attitude 'Origami'"}]}
# {'null': [{'special': "Ne pas connaître l'attitude 'Météore'"}]}
# {'null': [{'special': "Ne pas connaître l'attitude 'Découpage'"}]}
# {'null': [{'special': "Ne pas connaître l'attitude 'Lance glacée de Jiva'"}]}
# {'null': [{'special': "Ne pas connaître l'attitude 'Shariva'"}]}
# {'null': [{'special': "Ne pas connaître l'attitude 'Tire sur mon doigt'"}]}
# {'null': [{'special': "Ne pas connaître l'attitude 'Danse de Barbi Cajob'"}]}
# {'null': [{'special': "Ne pas posséder l'objet 'Coquetel airéalitai'"}]}
# {'null': [{'special': '< 25'}]}
# {'null': [{'special': '< 25'}]}
# {'null': [{'special': '< 25'}]}
# {'null': [{'special': "Ne pas posséder l'objet 'Goût de Shigekax Poire'"}]}
# {'null': [{'special': "Ne pas posséder l'objet 'Goût de Shigekax Vanille'"}]}
# {'null': [{'special': "Ne pas posséder l'objet 'Goût de Shigekax Praline'"}]}
# {'et': [{'ou': [{'special': 'Sous-zone : Port de givre'}, {'special': 'Sous-zone : La Bourgade'}, {'special': 'Sous-zone : Champs de glace'}, {'special': 'Sous-zone : Forêt des pins perdus'}, {'special': 'Sous-zone : Lac gelé'}]}, {'special': 'Map différente de : [ -68 : -34 ]'}]}
# {'null': [{'special': "Ne pas connaître l'attitude 'Téméraire'"}]}
# {'null': [{'special': "Ne pas connaître l'attitude 'Être frigorifié'"}]}
# {'null': [{'special': "Ne pas connaître l'attitude 'Joie'"}]}
# {'null': [{'special': "Ne pas connaître l'attitude 'Lever le pouce'"}]}
# {'null': [{'special': "Ne pas connaître l'attitude 'Bâiller'"}]}
# {'null': [{'special': "Ne pas connaître l'attitude 'Coucou'"}]}
# {'null': [{'special': "Ne pas connaître l'attitude 'Poing levé'"}]}
# {'null': [{'special': "Ne pas connaître l'attitude 'Motus'"}]}
# {'null': [{'special': "Ne pas posséder l'objet 'Effet Gumizes'"}]}
# {'null': [{'special': "Ne pas connaître l'attitude 'Halouine'"}]}
# {'null': [{'special': "Ne pas connaître l'attitude 'Longue-Vue'"}]}
# {'null': [{'special': "Ne pas connaître l'attitude 'Offrir un gâteau'"}]}
# {'null': [{'special': "Ne pas connaître l'attitude 'Huer'"}]}
# {'null': [{'special': "Ne pas connaître l'attitude 'Cracheur de Feu'"}]}
# {'null': [{'special': "Ne pas connaître l'attitude 'Mains derrière le dos'"}]}
# {'null': [{'special': "Ne pas connaître l'attitude 'Transcendant'"}]}
# {'null': [{'special': "Ne pas connaître l'attitude 'Colère de Bolgrot'"}]}
# {'null': [{'special': "Ne pas connaître l'attitude 'Duelliste'"}]}
# {'null': [{'special': "Ne pas connaître l'attitude 'Gonfler un ballon'"}]}
# {'null': [{'special': "Ne pas connaître l'attitude 'Coucou'"}]}
# {'null': [{'special': "Ne pas connaître l'attitude 'Étendard de Guilde victorieuse'"}]}
# {'null': [{'special': "Ne pas connaître l'attitude 'Coupe Dofus'"}]}
# {'et': [{'null': [{'special': "Quête 'Faire le mort' en cours"}]}, {'special': "Ne pas posséder l'objet 'Chafer '"}]}
# {'null': [{'special': "Ne pas connaître l'attitude 'Magmatique'"}]}
# {'null': [{'special': "Ne pas connaître l'attitude 'Zombique'"}]}
# {'null': [{'special': "Ne pas connaître l'attitude 'Supporter Millenium S2'"}]}
# {'null': [{'special': "Ne pas connaître l'attitude 'Supporter Batailleurs Glorieux S3'"}]}
# {'null': [{'special': "Ne pas posséder l'objet 'Déguisement de Champêtrouille'"}]}
# {'null': [{'special': "Ne pas posséder l'objet 'Déguisement de Chauffe-Soutrille'"}]}
# {'null': [{'special': "Ne pas posséder l'objet 'Déguisement de Bouftou d'Halouine'"}]}
# {'null': [{'special': "Ne pas posséder l'objet 'Goût de Koukawa Pomme'"}]}
# {'null': [{'special': "Ne pas posséder l'objet 'Goût de Koukawabi Fraise Citron'"}]}
# {'null': [{'special': "Ne pas posséder l'objet 'Goût de Koukawabi Pomme Fraise'"}]}
# {'null': [{'special': "Ne pas connaître l'attitude 'J'ai faim'"}]}
# {'null': [{'special': "Ne pas connaître l'attitude 'Saut de Wapin'"}]}
# {'null': [{'special': "Ne pas connaître l'attitude 'Coeur brisé'"}]}
# {'null': [{'special': "Ne pas posséder l'objet 'Goût de Perlequin Chocolat'"}]}
# {'null': [{'special': "Ne pas posséder l'objet 'Goût de Perlequin Melon'"}]}
# {'null': [{'special': "Ne pas posséder l'objet 'Goût de Perlequin Pomme'"}]}
# {'null': [{'special': "Ne pas posséder l'objet 'Goût de Perlequin Vanille'"}]}
# {'null': [{'special': "Ne pas connaître l'attitude 'Chanter'"}]}
# {'null': [{'special': "Ne pas connaître l'attitude 'Sauvage'"}]}
# {'null': [{'special': "Ne pas connaître l'attitude 'Balai magique'"}]}
# {'null': [{'special': "Ne pas connaître l'attitude 'Lancer un dé'"}]}
# {'null': [{'special': "Ne pas connaître l'attitude 'Roulette'"}]}
# {'null': [{'special': "Ne pas posséder l'objet 'Goût de Perlequin d'Ecaflip City'"}]}
# {'null': [{'special': "Ne pas connaître l'attitude 'Charmeur de Cooleuvre'"}]}
# {'null': [{'special': "Ne pas connaître l'attitude 'Snap'"}]}
# {'null': [{'special': "Quête 'La danse de la dissonance' achevée"}]}
# {'null': [{'special': "Ne pas connaître l'attitude 'Supporter Solary'"}]}
# {'null': [{'special': "Ne pas connaître l'attitude 'Avalanche de quêtes'"}]}
# {'null': [{'special': "Ne pas connaître l'attitude 'Dragon Ocre'"}]}
# {'null': [{'<': ['PA', 12]}]}
# {'null': [{'<': ['PA', 12]}]}
# {'null': [{'<': ['PA', 12]}]}
# {'null': [{'<': ['PA', 12]}]}
# {'null': [{'<': ['PA', 12]}]}
# {'null': [{'<': ['PA', 12]}]}
# {'null': [{'<': ['PA', 12]}]}
# {'null': [{'<': ['PA', 12]}]}
# {'null': [{'<': ['PA', 12]}]}
# {'null': [{'<': ['PA', 12]}]}
# {'null': [{'<': ['PA', 12]}]}
# {'null': [{'<': ['PA', 12]}]}
# {'null': [{'<': ['PA', 12]}]}
# {'null': [{'<': ['PA', 12]}]}
# {'null': [{'<': ['PA', 12]}]}
# {'null': [{'<': ['PA', 12]}]}
# {'null': [{'<': ['PA', 12]}]}
# {'null': [{'<': ['PA', 12]}]}
# {'null': [{'<': ['PA', 12]}]}
# {'null': [{'<': ['PA', 12]}]}
# {'null': [{'<': ['PA', 12]}]}
# {'null': [{'<': ['PA', 12]}]}
# {'null': [{'<': ['PA', 12]}]}
# {'null': [{'<': ['PA', 12]}]}
# {'null': [{'<': ['PA', 12]}]}
# {'null': [{'<': ['PA', 12]}]}
# {'null': [{'<': ['PA', 12]}]}
# {'null': [{'<': ['PA', 12]}]}
# {'null': [{'<': ['PA', 12]}]}
# {'null': [{'<': ['PA', 12]}]}
# {'null': [{'<': ['PA', 12]}]}
# {'null': [{'<': ['PA', 12]}]}
# {'null': [{'<': ['PA', 12]}]}
# {'et': [{'<': ['Intelligence de base', 560]}, {'<': ['Chance de base', 560]}, {'<': ['Agilité de base', 560]}]}
# {'null': [{'<': ['PA', 12]}]}
# {'null': [{'<': ['PA', 12]}]}
# {'null': [{'<': ['PA', 12]}]}
# {'null': [{'<': ['PA', 12]}]}
# {'null': [{'<': ['PM', 6]}]}
# {'null': [{'<': ['PA', 11]}]}
# {'null': [{'<': ['Force', 600]}]}
# {'null': [{'<': ['PM', 6]}]}
# {'null': [{'<': ['PA', 12]}]}
# {'null': [{'<': ['Force', 600]}]}
# {'null': [{'<': ['Agilité de base', 600]}]}
# {'null': [{'<': ['Force', 600]}]}
# {'null': [{'<': ['Intelligence de base', 600]}]}
# {'null': [{'<': ['Force', 600]}]}
# {'null': [{'<': ['Chance de base', 600]}]}
# {'null': [{'special': "Posséder l'objet 'Dofus Abyssal'"}]}
# {'null': [{'special': "Posséder l'objet ''"}]}
# {'null': [{'special': "Posséder l'objet 'Dofus Nébuleux'"}]}
# {'null': [{'special': "Posséder l'objet 'Dofus Vulbis'"}]}
# {'null': [{'special': "Posséder l'objet 'Dofus Forgelave'"}]}
# {'null': [{'<': ['PA', 12]}]}
# {'et': [{'>': ['Force', 250]}, {'>': ['Intelligence de base', 250]}, {'>': ['Chance de base', 250]}, {'>': ['Agilité de base', 250]}]}
# {'null': [{'special': "Posséder l'objet 'Dofus Ocre'"}]}
# {'null': [{'special': "Posséder l'objet 'Dofus Turquoise'"}]}
# {'null': [{'>': ['Agilité de base', 140]}]}
# {'null': [{'<': ['PA', 12]}]}
# {'null': [{'special': "Posséder l'objet 'Dorigami'"}]}
# {'null': [{'special': "Quête 'Yonkwa : Voie du sabre' achevée"}]}
# {'et': [{'>': ['Force', 200]}, {'>': ['Intelligence de base', 200]}, {'>': ['Chance de base', 200]}, {'>': ['Agilité de base', 200]}]}
# {'null': [{'special': "Posséder l'objet 'Domakuro'"}]}
# {'null': [{'special': "Posséder l'objet 'Dofus Pourpre'"}]}
# {'null': [{'<': ['PM', 6]}]}
# {'null': [{'special': "Posséder l'objet 'Dofus des Veilleurs'"}]}
# {'null': [{'special': "Posséder l'objet 'Dofus Émeraude'"}]}
# {'null': [{'>': ['Force', 90]}]}
# {'null': [{'special': 'Être un Enutrof'}]}
# {'null': [{'special': "Posséder l'objet 'Dokoko'"}]}
# {'et': [{'>': ['Sagesse de base', 30]}, {'>': ['Vitalité de base', 50]}]}
# {'null': [{'>': ['Intelligence de base', 90]}]}
# {'et': [{'special': 'Être de sexe masculin'}, {'special': "Quête 'Le pouvoir des fleurs' achevée"}]}
# {'et': [{'special': 'Être de sexe féminin'}, {'special': "Quête 'Le pouvoir des fleurs' achevée"}]}
# {'null': [{'special': "Posséder l'objet 'Dofus Cawotte'"}]}
# {'null': [{'special': 'Être un Enutrof'}]}
# {'null': [{'special': 'Alignement 1'}]}
# {'null': [{'special': 'Alignement 2'}]}
# {'et': [{'special': 'Alignement 1'}, {'>': ["Niveau d'alignement", 10]}]}
# {'null': [{'special': "Posséder l'objet 'Dofus Cacao'"}]}
# {'null': [{'>': ['Kamas', 100000]}]}
# {'null': [{'>': ['Force', 90]}]}
# {'null': [{'special': "Ne pas posséder l'objet 'Goulyfié'"}]}
# {'null': [{'special': "Ne pas posséder l'objet 'Goulyfié'"}]}
# {'null': [{'special': "Ne pas posséder l'objet 'Goulyfié'"}]}
# {'null': [{'>': ['Intelligence de base', 49]}]}
# {'null': [{'special': "Ne pas posséder l'objet 'Goulyfié'"}]}
# {'null': [{'special': "Ne pas posséder l'objet 'Goulyfié'"}]}
# {'null': [{'>': ['Agilité de base', 50]}]}
# {'null': [{'special': "Ne pas posséder l'objet 'Goulyfié'"}]}
# {'null': [{'>': ['Force', 59]}]}
# {'null': [{'>': ['Chance de base', 50]}]}
# {'null': [{'>': ['Chance de base', 30]}]}
# {'et': [{'>': ['Sagesse de base', 49]}, {'special': 'Alignement 1'}]}
# {'et': [{'>': ['Sagesse de base', 49]}, {'special': 'Alignement 2'}]}
# {'null': [{'>': ['Vitalité de base', 119]}]}
# {'et': [{'special': 'Alignement 1'}, {'>': ["Niveau d'alignement", 20]}]}
# {'et': [{'<': ['Force', 40]}, {'>': ['Intelligence de base', 80]}]}
# {'et': [{'<': ['Intelligence de base', 100]}, {'<': ['Chance de base', 100]}]}
# {'null': [{'>': ['Chance de base', 10]}]}
# {'ou': [{'special': 'Bûcheron > Niv. 180'}, {'special': 'Mineur > Niv. 180'}, {'special': 'Pêcheur > Niv. 180'}, {'special': 'Paysan > Niv. 180'}, {'special': 'Alchimiste > Niv. 180'}, {'special': 'Chasseur > Niv. 180'}]}
# {'null': [{'special': "Posséder l'objet 'Dofus Argenté'"}]}
# {'ou': [{'special': 'Bûcheron > Niv. 120'}, {'special': 'Mineur > Niv. 120'}, {'special': 'Pêcheur > Niv. 120'}, {'special': 'Paysan > Niv. 120'}, {'special': 'Alchimiste > Niv. 120'}, {'special': 'Chasseur > Niv. 120'}]}
# {'ou': [{'special': 'Bûcheron > Niv. 80'}, {'special': 'Mineur > Niv. 80'}, {'special': 'Pêcheur > Niv. 80'}, {'special': 'Paysan > Niv. 80'}, {'special': 'Alchimiste > Niv. 80'}, {'special': 'Chasseur > Niv. 80'}]}
# {'ou': [{'et': [{'special': 'Mois = Aperirel'}, {'<': ['Jour(s)', 9]}]}, {'special': 'Droits = 0'}]}
# {'ou': [{'special': 'Bûcheron > Niv. 40'}, {'special': 'Mineur > Niv. 40'}, {'special': 'Pêcheur > Niv. 40'}, {'special': 'Paysan > Niv. 40'}, {'special': 'Alchimiste > Niv. 40'}, {'special': 'Chasseur > Niv. 40'}]}
# {'et': [{'special': 'Alignement 2'}, {'>': ["Niveau d'alignement", 30]}]}
# {'null': [{'special': 'Alignement 2'}]}
# {'null': [{'special': 'Être de sexe féminin'}]}
# {'null': [{'special': 'Être de sexe masculin'}]}
# {'null': [{'special': 'Serveur = Shika'}]}
# {'et': [{'>': ['Force', 350]}, {'>': ['Agilité de base', 350]}]}
# {'et': [{'>': ['Force', 400]}, {'>': ['Agilité de base', 400]}, {'<': ['PA', 12]}]}
# {'et': [{'>': ['Intelligence de base', 400]}, {'>': ['Chance de base', 400]}, {'>': ['Agilité de base', 400]}]}
# {'et': [{'>': ['Agilité de base', 449]}, {'>': ['Force', 449]}]}
# {'null': [{'<': ['PA', 12]}]}
# {'null': [{'<': ['PA', 12]}]}
# {'ou': [{'>': ['Force', 450]}, {'>': ['Agilité de base', 450]}]}
# {'et': [{'>': ['Force', 449]}, {'>': ['Chance de base', 449]}]}
# {'et': [{'>': ['Force', 450]}, {'>': ['Chance de base', 450]}]}
# {'et': [{'>': ['Force', 400]}, {'>': ['Intelligence de base', 400]}, {'>': ['Chance de base', 400]}]}
# {'et': [{'>': ['Intelligence de base', 400]}, {'>': ['Agilité de base', 400]}]}
# {'et': [{'>': ['Intelligence de base', 499]}, {'>': ['Chance de base', 499]}]}
# {'et': [{'>': ['Agilité de base', 300]}, {'>': ['Chance de base', 300]}]}
# {'et': [{'>': ['Chance de base', 400]}, {'>': ['Agilité de base', 400]}]}
# {'et': [{'>': ['Intelligence de base', 349]}, {'>': ['Force', 349]}, {'>': ['Agilité de base', 349]}]}
# {'et': [{'>': ['Intelligence de base', 449]}, {'>': ['Chance de base', 449]}]}
# {'et': [{'>': ['Force', 300]}, {'>': ['Agilité de base', 300]}]}
# {'et': [{'>': ['Force', 300]}, {'>': ['Chance de base', 300]}]}
# {'et': [{'>': ['Force', 350]}, {'>': ['Chance de base', 350]}]}
# {'null': [{'>': ['Intelligence de base', 559]}]}
# {'et': [{'>': ['Intelligence de base', 400]}, {'>': ['Force', 400]}, {'>': ['Chance de base', 400]}, {'>': ['Agilité de base', 400]}]}
# {'et': [{'>': ['Force', 400]}, {'>': ['Chance de base', 400]}]}
# {'et': [{'>': ['Agilité de base', 400]}, {'>': ['Force', 400]}]}
# {'et': [{'>': ['Agilité de base', 450]}, {'>': ['Intelligence de base', 450]}]}
# {'et': [{'>': ['Intelligence de base', 550]}, {'>': ['Chance de base', 550]}]}
# {'et': [{'>': ['Intelligence de base', 350]}, {'>': ['Force', 350]}, {'>': ['Agilité de base', 350]}, {'>': ['Chance de base', 350]}]}
# {'et': [{'>': ['Agilité de base', 350]}, {'>': ['Chance de base', 350]}, {'>': ['Intelligence de base', 350]}, {'>': ['Force', 350]}]}
# {'et': [{'>': ['Chance de base', 350]}, {'>': ['Intelligence de base', 200]}]}
# {'et': [{'>': ['Intelligence de base', 350]}, {'>': ['Chance de base', 250]}]}
# {'et': [{'>': ['Intelligence de base', 400]}, {'>': ['Force', 200]}]}
# {'et': [{'>': ['Chance de base', 300]}, {'>': ['Agilité de base', 300]}]}
# {'et': [{'>': ['Force', 400]}, {'>': ['Agilité de base', 400]}]}
# {'et': [{'>': ['Intelligence de base', 400]}, {'>': ['Agilité de base', 400]}]}
# {'et': [{'>': ['Force', 350]}, {'ou': [{'>': ['Intelligence de base', 350]}, {'>': ['Chance de base', 350]}, {'>': ['Agilité de base', 350]}]}]}
# {'null': [{'>': ['Chance de base', 450]}]}
# {'et': [{'>': ['Chance de base', 400]}, {'>': ['Agilité de base', 400]}]}
# {'null': [{'>': ['Chance de base', 400]}]}
# {'null': [{'>': ['Force', 450]}]}
# {'et': [{'>': ['Force', 350]}, {'>': ['Intelligence de base', 250]}]}
# {'null': [{'>': ['Intelligence de base', 500]}]}
# {'et': [{'>': ['Agilité de base', 300]}, {'>': ['Chance de base', 300]}, {'>': ['Force', 200]}]}
# {'et': [{'>': ['Intelligence de base', 400]}, {'>': ['Force', 300]}]}
# {'et': [{'>': ['Intelligence de base', 250]}, {'>': ['Agilité de base', 250]}, {'>': ['Chance de base', 250]}]}
# {'et': [{'>': ['Force', 300]}, {'>': ['Intelligence de base', 300]}]}
# {'et': [{'>': ['Intelligence de base', 300]}, {'>': ['Chance de base', 250]}]}
# {'et': [{'>': ['Force', 400]}, {'>': ['Intelligence de base', 400]}]}
# {'et': [{'>': ['Force', 200]}, {'>': ['Intelligence de base', 200]}, {'>': ['Chance de base', 200]}, {'>': ['Agilité de base', 200]}]}
# {'et': [{'>': ['Force', 200]}, {'>': ['Chance de base', 200]}, {'>': ['Intelligence de base', 90]}]}
# {'null': [{'>': ['Chance de base', 450]}]}
# {'et': [{'<': ['PM', 6]}, {'>': ['Sagesse de base', 350]}]}
# {'et': [{'>': ['Agilité de base', 300]}, {'>': ['Chance de base', 300]}]}
# {'et': [{'>': ['Agilité de base', 350]}, {'>': ['Vitalité de base', 1500]}]}
# {'null': [{'>': ['Agilité de base', 450]}]}
# {'et': [{'>': ['Agilité de base', 300]}, {'>': ['Force', 200]}]}
# {'et': [{'>': ['Intelligence de base', 300]}, {'>': ['Agilité de base', 200]}]}
# {'et': [{'>': ['Intelligence de base', 250]}, {'>': ['Force', 200]}]}
# {'et': [{'>': ['Agilité de base', 200]}, {'>': ['Chance de base', 200]}, {'>': ['Force', 200]}]}
# {'et': [{'>': ['Agilité de base', 300]}, {'>': ['Intelligence de base', 300]}]}
# {'et': [{'>': ['Intelligence de base', 350]}, {'>': ['Agilité de base', 200]}]}
# {'null': [{'>': ['Force', 90]}]}
# {'et': [{'>': ['Chance de base', 300]}, {'>': ['Agilité de base', 300]}]}
# {'null': [{'>': ['Vitalité de base', 2000]}]}
# {'null': [{'>': ['Chance de base', 350]}]}
# {'et': [{'>': ['Force', 300]}, {'>': ['Intelligence de base', 300]}]}
# {'et': [{'>': ['Force', 200]}, {'>': ['Intelligence de base', 140]}, {'>': ['Chance de base', 140]}, {'>': ['Agilité de base', 140]}]}
# {'null': [{'>': ['Vitalité de base', 1200]}]}
# {'et': [{'>': ['Force', 300]}, {'>': ['Agilité de base', 140]}]}
# {'null': [{'>': ['Chance de base', 250]}]}
# {'et': [{'>': ['Intelligence de base', 350]}, {'>': ['Sagesse de base', 180]}]}
# {'et': [{'>': ['Force', 200]}, {'>': ['Intelligence de base', 200]}]}
# {'et': [{'>': ['Force', 200]}, {'>': ['Intelligence de base', 200]}]}
# {'null': [{'>': ['PM', 5]}]}
# {'et': [{'>': ['Intelligence de base', 300]}, {'>': ['Force', 90]}]}
# {'null': [{'>': ['Chance de base', 250]}]}
# {'et': [{'>': ['Agilité de base', 250]}, {'>': ['Chance de base', 250]}, {'>': ['Force', 140]}]}
# {'et': [{'>': ['Agilité de base', 200]}, {'>': ['Force', 200]}]}
# {'et': [{'>': ['Force', 250]}, {'>': ['Chance de base', 250]}]}
# {'et': [{'>': ['Intelligence de base', 140]}, {'>': ['Sagesse de base', 300]}]}
# {'et': [{'>': ['Chance de base', 250]}, {'>': ['Intelligence de base', 250]}]}
# {'et': [{'>': ['Force', 350]}, {'>': ['Agilité de base', 200]}]}
# {'et': [{'>': ['Intelligence de base', 400]}, {'>': ['Chance de base', 250]}, {'>': ['Sagesse de base', 140]}]}
# {'et': [{'>': ['Force', 250]}, {'>': ['Agilité de base', 200]}]}
# {'et': [{'>': ['Force', 450]}, {'>': ['Vitalité de base', 450]}]}
# {'et': [{'>': ['Intelligence de base', 250]}, {'>': ['Chance de base', 250]}]}
# {'et': [{'>': ['Force', 250]}, {'>': ['Chance de base', 250]}, {'>': ['Intelligence de base', 140]}]}
# {'et': [{'>': ['Intelligence de base', 250]}, {'>': ['Agilité de base', 250]}]}
# {'null': [{'>': ['Force', 350]}]}
# {'et': [{'>': ['Agilité de base', 300]}, {'>': ['Intelligence de base', 300]}]}
# {'null': [{'special': 'Objet non équipable'}]}
# {'et': [{'>': ['Force', 350]}, {'>': ['Agilité de base', 200]}, {'<': ['PM', 6]}]}
# {'et': [{'>': ['Agilité de base', 300]}, {'>': ['Intelligence de base', 300]}]}
# {'et': [{'>': ['Intelligence de base', 250]}, {'>': ['Chance de base', 250]}]}
# {'et': [{'>': ['Sagesse de base', 250]}, {'>': ['Force', 300]}]}
# {'null': [{'>': ['Chance de base', 250]}]}
# {'et': [{'special': 'Map : [ -14 : 34 ]'}, {'special': "Quête 'Passe le fungus autour de toi' en cours"}]}
# {'null': [{'<': ['PA', 12]}]}
# {'et': [{'>': ['Intelligence de base', 300]}, {'>': ['Agilité de base', 300]}]}
# {'et': [{'special': 'Map : [ -14 : 34 ]'}, {'special': "Quête 'Passe le fungus autour de toi' en cours"}]}
# {'et': [{'>': ['Intelligence de base', 180]}, {'>': ['Force', 90]}]}
# {'null': [{'>': ['Agilité de base', 300]}]}
# {'et': [{'>': ['Vitalité de base', 300]}, {'>': ['Agilité de base', 300]}]}
# {'et': [{'>': ['Chance de base', 140]}, {'>': ['Agilité de base', 140]}, {'>': ['Intelligence de base', 140]}]}
# {'null': [{'>': ['Chance de base', 450]}]}
# {'et': [{'>': ['Force', 250]}, {'>': ['Vitalité de base', 800]}]}
# {'et': [{'>': ['Force', 250]}, {'>': ['Intelligence de base', 250]}]}
# {'et': [{'>': ['Intelligence de base', 300]}, {'>': ['Sagesse de base', 200]}]}
# {'et': [{'>': ['Agilité de base', 300]}, {'>': ['Intelligence de base', 140]}]}
# {'null': [{'>': ['Agilité de base', 300]}]}
# {'et': [{'>': ['Agilité de base', 200]}, {'>': ['Intelligence de base', 90]}, {'>': ['Force', 90]}]}
# {'et': [{'>': ['Agilité de base', 250]}, {'>': ['Force', 140]}]}
# {'et': [{'>': ['Force', 450]}, {'ou': [{'special': "Quête 'Shodanwa : Perfection martiale' achevée"}, {'null': [{'special': "Quête 'Shodanwa : Perfection martiale' en cours"}]}]}]}
# {'et': [{'>': ['Chance de base', 250]}, {'>': ['Force', 250]}]}
# {'et': [{'>': ['Agilité de base', 250]}, {'>': ['Intelligence de base', 90]}]}
# {'et': [{'>': ['Intelligence de base', 250]}, {'>': ['Chance de base', 250]}]}
# {'et': [{'>': ['Intelligence de base', 140]}, {'>': ['Vitalité de base', 200]}]}
# {'et': [{'>': ['Chance de base', 250]}, {'>': ['Force', 140]}]}
# {'null': [{'>': ['Agilité de base', 200]}]}
# {'et': [{'>': ['Intelligence de base', 450]}, {'>': ['Vitalité de base', 200]}]}
# {'et': [{'>': ['Force', 350]}, {'>': ['Vitalité de base', 400]}]}
# {'et': [{'>': ['Force', 140]}, {'>': ['Intelligence de base', 75]}, {'>': ['Chance de base', 75]}, {'>': ['Agilité de base', 75]}]}
# {'et': [{'>': ['Intelligence de base', 300]}, {'>': ['Force', 130]}]}
# {'et': [{'>': ['Force', 140]}, {'>': ['Vitalité de base', 400]}, {'>': ['Intelligence de base', 50]}, {'>': ['Agilité de base', 50]}]}
# {'et': [{'>': ['Force', 250]}, {'>': ['Agilité de base', 90]}]}
# {'et': [{'>': ['Agilité de base', 120]}, {'>': ['Intelligence de base', 120]}, {'>': ['Chance de base', 120]}, {'>': ['Vitalité de base', 300]}]}
# {'et': [{'>': ['Chance de base', 400]}, {'>': ['Vitalité de base', 250]}]}
# {'null': [{'>': ['Agilité de base', 250]}]}
# {'et': [{'>': ['Intelligence de base', 350]}, {'>': ['Force', 350]}]}
# {'et': [{'>': ['Intelligence de base', 250]}, {'>': ['Chance de base', 250]}]}
# {'et': [{'>': ['Sagesse de base', 250]}, {'>': ['Vitalité de base', 500]}]}
# {'et': [{'>': ['Agilité de base', 200]}, {'>': ['Chance de base', 200]}]}
# {'et': [{'>': ['Intelligence de base', 140]}, {'>': ['Agilité de base', 90]}, {'>': ['Chance de base', 90]}, {'>': ['Force', 90]}]}
# {'et': [{'>': ['Chance de base', 140]}, {'>': ['Agilité de base', 200]}]}
# {'null': [{'>': ['Vitalité de base', 500]}]}
# {'et': [{'>': ['Chance de base', 200]}, {'>': ['Vitalité de base', 300]}]}
# {'et': [{'>': ['Force', 250]}, {'>': ['Agilité de base', 90]}]}
# {'et': [{'>': ['Force', 140]}, {'>': ['Agilité de base', 140]}, {'>': ['Intelligence de base', 140]}]}
# {'et': [{'>': ['Agilité de base', 200]}, {'>': ['Force', 200]}]}
# {'et': [{'>': ['Agilité de base', 250]}, {'>': ['Sagesse de base', 140]}]}
# {'et': [{'>': ['Chance de base', 250]}, {'>': ['Agilité de base', 90]}]}
# {'et': [{'>': ['Force', 200]}, {'>': ['Agilité de base', 120]}, {'>': ['Vitalité de base', 300]}]}
# {'et': [{'>': ['Agilité de base', 200]}, {'>': ['Chance de base', 70]}]}
# {'et': [{'>': ['Intelligence de base', 300]}, {'>': ['Chance de base', 140]}]}
# {'et': [{'>': ['Force', 250]}, {'>': ['Vitalité de base', 200]}]}
# {'et': [{'>': ['Intelligence de base', 300]}, {'>': ['Vitalité de base', 300]}, {'>': ['Agilité de base', 90]}]}
# {'et': [{'>': ['Force', 250]}, {'>': ['Intelligence de base', 140]}]}
# ...
# {'et': [{'>': ['Force', 90]}, {'>': ['Vitalité de base', 50]}]}
# {'et': [{'>': ['Agilité de base', 60]}, {'>': ['Vitalité de base', 15]}]}
# {'et': [{'>': ['Chance de base', 20]}, {'>': ['Agilité de base', 20]}, {'>': ['Vitalité de base', 20]}]}
# {'et': [{'>': ['Intelligence de base', 60]}, {'>': ['Force', 20]}]}
# {'et': [{'>': ['Intelligence de base', 50]}, {'>': ['Agilité de base', 18]}]}
# {'et': [{'>': ['Vitalité de base', 90]}, {'>': ['Sagesse de base', 50]}]}
# {'et': [{'>': ['Agilité de base', 40]}, {'>': ['Chance de base', 40]}]}
# {'et': [{'>': ['Sagesse de base', 17]}, {'>': ['Intelligence de base', 53]}]}
# {'null': [{'>': ['Chance de base', 50]}]}
# {'null': [{'>': ['Chance de base', 30]}]}
# {'null': [{'>': ['Vitalité de base', 70]}]}
# {'et': [{'>': ['Agilité de base', 62]}, {'>': ['Sagesse de base', 22]}]}
# {'null': [{'>': ['Agilité de base', 47]}]}
# {'et': [{'>': ['Force', 50]}, {'>': ['Agilité de base', 40]}, {'>': ['Chance de base', 30]}]}
# {'et': [{'>': ['Force', 104]}, {'>': ['Vitalité de base', 52]}, {'>': ['Agilité de base', 20]}]}
# {'et': [{'>': ['Chance de base', 60]}, {'>': ['Vitalité de base', 40]}]}
# {'et': [{'>': ['Chance de base', 60]}, {'>': ['Intelligence de base', 60]}]}
# {'et': [{'>': ['Agilité de base', 40]}, {'>': ['Vitalité de base', 40]}, {'>': ['Force', 15]}]}
# {'et': [{'>': ['Intelligence de base', 45]}, {'>': ['Force', 8]}]}
# {'et': [{'>': ['Chance de base', 30]}, {'>': ['Agilité de base', 10]}]}
# {'ou': [{'special': "Quête 'Le jour des assassins' en cours"}, {'special': "Quête 'Le jour des assassins' achevée"}]}
# {'et': [{'>': ['Intelligence de base', 30]}, {'>': ['Sagesse de base', 20]}]}
# {'et': [{'>': ['Force', 30]}, {'>': ['Intelligence de base', 30]}]}
# {'et': [{'>': ['Force', 42]}, {'>': ['Intelligence de base', 10]}]}
# {'et': [{'>': ['Agilité de base', 40]}, {'>': ['Force', 11]}, {'>': ['Intelligence de base', 11]}]}
# {'et': [{'>': ['Sagesse de base', 20]}, {'>': ['Intelligence de base', 20]}, {'>': ['Chance de base', 20]}]}
# {'et': [{'>': ['Vitalité de base', 90]}, {'>': ['Sagesse de base', 50]}]}
# {'null': [{'>': ['Agilité de base', 46]}]}
# {'et': [{'>': ['Vitalité de base', 30]}, {'>': ['Sagesse de base', 10]}]}
# {'null': [{'>': ['Agilité de base', 60]}]}
# {'null': [{'>': ['Agilité de base', 46]}]}
# {'et': [{'>': ['Intelligence de base', 50]}, {'>': ['Vitalité de base', 30]}]}
# {'null': [{'>': ['Force', 90]}]}
# {'null': [{'>': ['Intelligence de base', 65]}]}
# {'null': [{'>': ['Agilité de base', 60]}]}
# {'null': [{'>': ['Chance de base', 50]}]}
# {'et': [{'>': ['Intelligence de base', 15]}, {'>': ['Force', 15]}]}
# {'et': [{'>': ['Force', 4]}, {'>': ['Chance de base', 30]}]}
# {'null': [{'>': ['Agilité de base', 80]}]}
# {'null': [{'>': ['Intelligence de base', 60]}]}
# {'null': [{'>': ['Vitalité de base', 60]}]}
# {'et': [{'>': ['Intelligence de base', 30]}, {'>': ['Sagesse de base', 30]}]}
# {'et': [{'>': ['Intelligence de base', 50]}, {'>': ['Vitalité de base', 50]}]}
# {'et': [{'>': ['Force', 50]}, {'>': ['Vitalité de base', 50]}]}
# {'et': [{'>': ['Agilité de base', 41]}, {'>': ['Force', 16]}]}
# {'et': [{'>': ['Chance de base', 50]}, {'>': ['Vitalité de base', 50]}]}
# {'et': [{'>': ['Agilité de base', 50]}, {'>': ['Vitalité de base', 50]}]}
# {'et': [{'>': ['Force', 10]}, {'>': ['Chance de base', 30]}]}
# {'et': [{'>': ['Intelligence de base', 50]}, {'>': ['Agilité de base', 40]}]}
# {'et': [{'>': ['Force', 80]}, {'>': ['Vitalité de base', 40]}, {'>': ['Agilité de base', 40]}]}
# {'null': [{'>': ['Force', 60]}]}
# {'null': [{'>': ['Agilité de base', 40]}]}
# {'null': [{'>': ['Agilité de base', 40]}]}
# {'null': [{'>': ['Agilité de base', 30]}]}
# {'null': [{'>': ['Force', 50]}]}
# {'null': [{'special': "Quête 'Manque de moule' en cours"}]}
# {'et': [{'>': ['Vitalité de base', 20]}, {'>': ['Sagesse de base', 20]}]}
# {'et': [{'>': ['Agilité de base', 39]}, {'>': ['Sagesse de base', 5]}]}
# {'et': [{'>': ['Force', 50]}, {'>': ['Agilité de base', 12]}]}
# {'et': [{'>': ['Force', 40]}, {'>': ['Agilité de base', 5]}]}
# {'et': [{'>': ['Force', 30]}, {'>': ['Agilité de base', 36]}]}
# {'et': [{'>': ['Force', 50]}, {'>': ['Agilité de base', 20]}]}
# {'null': [{'>': ['Force', 20]}]}
# {'null': [{'>': ['Force', 50]}]}
# {'null': [{'>': ['Intelligence de base', 45]}]}
# {'null': [{'>': ['Agilité de base', 25]}]}
# {'et': [{'>': ['Intelligence de base', 80]}, {'>': ['Sagesse de base', 30]}]}
# {'et': [{'>': ['Vitalité de base', 10]}, {'>': ['Force', 10]}, {'>': ['Agilité de base', 10]}]}
# {'et': [{'>': ['Intelligence de base', 20]}, {'>': ['Sagesse de base', 5]}]}
# {'et': [{'>': ['Chance de base', 30]}, {'>': ['Intelligence de base', 34]}, {'>': ['Sagesse de base', 15]}]}
# {'et': [{'>': ['Force', 66]}, {'>': ['Agilité de base', 10]}]}
# {'null': [{'>': ['Intelligence de base', 35]}]}
# {'et': [{'>': ['Agilité de base', 55]}, {'>': ['Chance de base', 5]}]}
# {'null': [{'>': ['Force', 66]}]}
# {'null': [{'>': ['Vitalité de base', 40]}]}
# {'et': [{'>': ['Intelligence de base', 32]}, {'>': ['Agilité de base', 10]}]}
# {'null': [{'>': ['Chance de base', 30]}]}
# {'et': [{'>': ['Force', 10]}, {'>': ['Agilité de base', 30]}]}
# {'null': [{'>': ['Agilité de base', 30]}]}
# {'null': [{'>': ['Force', 50]}]}
# {'et': [{'>': ['Intelligence de base', 30]}, {'>': ['Chance de base', 5]}]}
# {'null': [{'>': ['Agilité de base', 30]}]}
# {'null': [{'>': ['Agilité de base', 50]}]}
# {'null': [{'>': ['Intelligence de base', 34]}]}
# {'null': [{'>': ['Sagesse de base', 50]}]}
# {'null': [{'>': ['Vitalité de base', 30]}]}
# {'null': [{'>': ['Chance de base', 20]}]}
# {'null': [{'>': ['Agilité de base', 40]}]}
# {'null': [{'>': ['Intelligence de base', 29]}]}
# {'null': [{'>': ['Chance de base', 10]}]}
# {'null': [{'>': ['Agilité de base', 30]}]}
# {'et': [{'>': ['Agilité de base', 28]}, {'>': ['Vitalité de base', 5]}]}
# {'et': [{'>': ['Agilité de base', 30]}, {'>': ['Chance de base', 5]}, {'>': ['Force', 10]}]}
# {'null': [{'>': ['Chance de base', 54]}]}
# {'null': [{'>': ['Intelligence de base', 50]}]}
# {'et': [{'>': ['Intelligence de base', 17]}, {'>': ['Chance de base', 5]}]}
# {'null': [{'>': ['Sagesse de base', 15]}]}
# {'null': [{'>': ['Sagesse de base', 11]}]}
# {'null': [{'>': ['Intelligence de base', 52]}]}
# {'et': [{'>': ['Force', 10]}, {'>': ['Intelligence de base', 16]}]}
# {'null': [{'>': ['Agilité de base', 30]}]}
# {'et': [{'>': ['Agilité de base', 40]}, {'>': ['Chance de base', 40]}]}
# {'et': [{'>': ['Force', 50]}, {'>': ['Sagesse de base', 5]}]}
# {'et': [{'>': ['Force', 10]}, {'>': ['Agilité de base', 28]}]}
# {'et': [{'>': ['Force', 24]}, {'>': ['Intelligence de base', 4]}]}
# {'et': [{'>': ['Agilité de base', 23]}, {'>': ['Force', 33]}]}
# {'null': [{'>': ['Agilité de base', 20]}]}
# {'null': [{'>': ['Chance de base', 15]}]}
# {'null': [{'>': ['Sagesse de base', 30]}]}
# {'null': [{'>': ['Vitalité de base', 30]}]}
# {'et': [{'>': ['Force', 10]}, {'>': ['Intelligence de base', 11]}]}
# {'null': [{'>': ['Force', 42]}]}
# {'et': [{'>': ['Force', 42]}, {'>': ['Agilité de base', 10]}]}
# {'null': [{'>': ['Force', 20]}]}
# {'null': [{'>': ['Intelligence de base', 10]}]}
# {'null': [{'>': ['Chance de base', 19]}]}
# {'null': [{'>': ['Agilité de base', 36]}]}
# {'et': [{'>': ['Intelligence de base', 12]}, {'>': ['Force', 6]}]}
# {'et': [{'>': ['Force', 34]}, {'>': ['Vitalité de base', 10]}]}
# {'et': [{'>': ['Force', 34]}, {'>': ['Vitalité de base', 5]}]}
# {'null': [{'>': ['Agilité de base', 17]}]}
# {'et': [{'>': ['Intelligence de base', 15]}, {'>': ['Force', 15]}]}
# {'null': [{'>': ['Intelligence de base', 16]}]}
# {'null': [{'>': ['Force', 32]}]}
# {'null': [{'>': ['Force', 30]}]}
# {'null': [{'>': ['Force', 70]}]}
# {'et': [{'>': ['Intelligence de base', 10]}, {'>': ['Force', 5]}]}
# {'null': [{'>': ['Vitalité de base', 20]}]}
# {'null': [{'>': ['Intelligence de base', 15]}]}
# {'et': [{'>': ['Force', 26]}, {'>': ['Agilité de base', 10]}]}
# {'null': [{'>': ['Force', 13]}]}
# {'null': [{'>': ['Chance de base', 10]}]}
# {'null': [{'>': ['Force', 12]}]}
# {'null': [{'>': ['Intelligence de base', 30]}]}
# {'null': [{'>': ['Force', 11]}]}
# {'null': [{'>': ['Intelligence de base', 9]}]}
# {'null': [{'>': ['Agilité de base', 14]}]}
# {'null': [{'>': ['Chance de base', 10]}]}
# {'null': [{'>': ['Agilité de base', 4]}]}
# {'null': [{'>': ['Force', 14]}]}
# {'null': [{'>': ['Agilité de base', 7]}]}
# {'et': [{'>': ['Force', 1]}, {'>': ['Chance de base', 5]}]}
# {'et': [{'>': ['Intelligence de base', 5]}, {'>': ['Force', 1]}]}
# {'null': [{'>': ['Intelligence de base', 9]}]}
# {'null': [{'>': ['Intelligence de base', 10]}]}
# {'null': [{'>': ['Vitalité de base', 2]}]}
# {'et': [{'special': 'Être un Ecaflip'}, {'special': 'Être de sexe masculin'}]}
# {'et': [{'special': 'Être un Ecaflip'}, {'special': 'Être de sexe féminin'}]}
# {'null': [{'special': "Quête 'L'éternelle moisson' en cours"}]}
# {'null': [{'special': "Quête 'Algue au rythme' en cours"}]}
# {'et': [{'special': "Quête 'Les métamorphoses d’un Tanuki' en cours"}, {'special': "Possède le sort Capture d'âmes"}]}
# {'null': [{'special': 'Etre abonné'}]}
# {'null': [{'special': 'Etre abonné'}]}
# {'null': [{'special': 'Etre abonné'}]}
# {'null': [{'special': 'Etre abonné'}]}
# {'null': [{'special': 'Etre abonné'}]}
# {'null': [{'special': 'Etre abonné'}]}
# {'null': [{'special': 'Etre abonné'}]}
# {'null': [{'special': 'Etre abonné'}]}
# {'null': [{'special': 'Etre abonné'}]}
# {'null': [{'special': 'Etre abonné'}]}
# {'null': [{'special': 'Etre abonné'}]}
# {'null': [{'special': 'Etre abonné'}]}
# {'null': [{'special': 'Être célibataire'}]}
# {'null': [{'special': 'Appartenir à une guilde'}]}
# {'null': [{'special': 'Etre abonné'}]}
# {'null': [{'special': 'Etre abonné'}]}
# {'null': [{'special': 'Etre abonné'}]}
# {'null': [{'special': 'Etre abonné'}]}
# {'null': [{'special': 'Etre abonné'}]}
# {'null': [{'special': 'Etre abonné'}]}
# {'null': [{'special': 'Etre abonné'}]}
# {'null': [{'special': 'Etre abonné'}]}
# {'null': [{'special': 'Etre abonné'}]}
# {'et': [{'special': 'Appartenir à une guilde'}, {'>': ['Niveau de guilde', 29]}]}
# {'et': [{'special': 'Appartenir à une guilde'}, {'special': 'Appartenir à une alliance'}]}
# {'null': [{'special': 'Etre abonné'}]}
# {'null': [{'special': 'Etre abonné'}]}
# {'null': [{'special': 'Etre abonné'}]}
# {'null': [{'special': 'Etre abonné'}]}
# {'null': [{'special': 'Etre abonné'}]}
# {'null': [{'special': 'Etre abonné'}]}
# {'null': [{'special': 'Etre abonné'}]}
# {'null': [{'special': 'Etre abonné'}]}
# {'null': [{'special': 'Etre abonné'}]}
# {'null': [{'special': 'Etre abonné'}]}
# {'null': [{'special': 'Etre abonné'}]}
# {'null': [{'special': 'Etre abonné'}]}
# {'null': [{'special': 'Etre abonné'}]}
# {'null': [{'special': 'Appartenir à une guilde'}]}
# {'null': [{'special': 'Etre abonné'}]}
# {'null': [{'special': 'Etre abonné'}]}
# {'null': [{'special': 'Etre abonné'}]}
# {'null': [{'special': 'Etre abonné'}]}
# {'null': [{'special': 'Etre abonné'}]}
# {'null': [{'special': 'Etre abonné'}]}
# {'null': [{'special': 'Etre abonné'}]}
# {'null': [{'special': 'Etre abonné'}]}
# {'null': [{'special': 'Etre abonné'}]}
# {'null': [{'special': 'Etre abonné'}]}
# {'null': [{'special': 'Etre abonné'}]}
# {'null': [{'special': 'Etre abonné'}]}
# {'null': [{'special': 'Etre abonné'}]}
# {'null': [{'special': 'Etre abonné'}]}
# {'null': [{'special': 'Etre abonné'}]}
# {'null': [{'special': 'Etre abonné'}]}
# {'null': [{'special': 'Etre abonné'}]}
# {'null': [{'special': 'Etre abonné'}]}
# {'null': [{'special': 'Etre abonné'}]}
# {'null': [{'special': 'Etre abonné'}]}
# {'null': [{'special': 'Etre abonné'}]}
# {'null': [{'special': 'Etre abonné'}]}
# {'null': [{'special': 'Etre abonné'}]}
# {'null': [{'special': 'Etre abonné'}]}
# {'null': [{'special': 'Etre abonné'}]}
# {'null': [{'special': 'Etre abonné'}]}
# {'null': [{'special': 'Etre abonné'}]}
# {'null': [{'special': 'Etre abonné'}]}
# {'null': [{'special': 'Etre abonné'}]}
# {'null': [{'special': 'Etre abonné'}]}
# {'null': [{'special': 'Etre abonné'}]}
# {'null': [{'special': 'Etre abonné'}]}
# {'null': [{'special': 'Etre abonné'}]}
# {'null': [{'special': 'Etre abonné'}]}
# {'null': [{'special': 'Etre abonné'}]}
# {'null': [{'special': 'Etre abonné'}]}
# {'null': [{'special': 'Etre abonné'}]}
# {'null': [{'special': 'Etre abonné'}]}
# {'null': [{'special': 'Etre abonné'}]}
# {'null': [{'special': 'Etre abonné'}]}
# {'null': [{'special': 'Etre abonné'}]}
# {'null': [{'special': 'Etre abonné'}]}
# {'null': [{'special': 'Etre abonné'}]}
# {'null': [{'special': 'Etre abonné'}]}
# {'null': [{'special': 'Etre abonné'}]}
# {'null': [{'special': 'Etre abonné'}]}
# {'null': [{'special': 'Etre abonné'}]}
# {'null': [{'special': 'Etre abonné'}]}
# {'null': [{'special': 'Etre abonné'}]}
# {'null': [{'special': 'Etre abonné'}]}
# {'null': [{'special': 'Etre abonné'}]}
# {'null': [{'special': 'Etre abonné'}]}
# {'null': [{'special': 'Etre abonné'}]}
# {'null': [{'special': 'Etre abonné'}]}
# {'null': [{'special': 'Etre abonné'}]}
# {'null': [{'special': 'Etre abonné'}]}
# {'null': [{'special': 'Etre abonné'}]}
# {'null': [{'special': 'Etre abonné'}]}
# {'null': [{'special': 'Etre abonné'}]}
# {'null': [{'special': 'Etre abonné'}]}
# {'null': [{'special': 'Etre abonné'}]}
# {'null': [{'special': 'Etre abonné'}]}
# {'null': [{'special': 'Etre abonné'}]}
# {'null': [{'special': 'Etre abonné'}]}
# {'null': [{'special': 'Etre abonné'}]}
# {'null': [{'special': 'Etre abonné'}]}
# {'null': [{'special': 'Etre abonné'}]}
# {'null': [{'special': 'Etre abonné'}]}
# {'null': [{'special': 'Etre abonné'}]}
# {'null': [{'special': 'Etre abonné'}]}
# {'null': [{'special': 'Etre abonné'}]}
# {'null': [{'special': 'Etre abonné'}]}
# {'null': [{'special': 'Etre abonné'}]}
# {'null': [{'special': 'Etre abonné'}]}
# {'null': [{'special': 'Etre abonné'}]}
# {'null': [{'special': 'Etre abonné'}]}
# {'null': [{'special': 'Etre abonné'}]}
# {'null': [{'special': 'Etre abonné'}]}
# {'null': [{'special': 'Etre abonné'}]}
# {'null': [{'special': 'Etre abonné'}]}
# {'null': [{'special': 'Etre abonné'}]}
# {'null': [{'special': 'Etre abonné'}]}
# {'null': [{'special': 'Etre abonné'}]}
# {'null': [{'special': 'Etre abonné'}]}
# {'null': [{'special': 'Etre abonné'}]}
# {'null': [{'special': 'Etre abonné'}]}
# {'null': [{'special': 'Etre abonné'}]}
# {'null': [{'special': 'Etre abonné'}]}
# {'null': [{'special': 'Etre abonné'}]}
# {'null': [{'special': 'Etre abonné'}]}
# {'null': [{'special': 'Etre abonné'}]}
# {'null': [{'special': 'Etre abonné'}]}
# {'null': [{'special': 'Etre abonné'}]}
# {'null': [{'special': 'Etre abonné'}]}
# {'null': [{'special': 'Etre abonné'}]}
# {'null': [{'special': 'Etre abonné'}]}
# {'null': [{'special': 'Etre abonné'}]}
# {'null': [{'special': 'Etre abonné'}]}
# {'null': [{'special': 'Etre abonné'}]}
# {'null': [{'special': 'Etre abonné'}]}
# {'null': [{'special': 'Etre abonné'}]}
# {'null': [{'special': 'Etre abonné'}]}
# {'null': [{'special': 'Etre abonné'}]}
# {'null': [{'special': 'Etre abonné'}]}
# {'null': [{'special': 'Etre abonné'}]}
# {'null': [{'special': 'Etre abonné'}]}
# {'null': [{'special': 'Etre abonné'}]}
# {'null': [{'special': 'Etre abonné'}]}
# {'null': [{'special': 'Etre abonné'}]}
# {'null': [{'special': 'Etre abonné'}]}
# {'null': [{'special': 'Etre abonné'}]}
# {'null': [{'special': 'Etre abonné'}]}
# {'null': [{'special': 'Etre abonné'}]}
# {'null': [{'special': 'Etre abonné'}]}
# {'null': [{'special': 'Etre abonné'}]}
# {'null': [{'special': 'Etre abonné'}]}
# {'null': [{'special': 'Etre abonné'}]}
# {'null': [{'special': 'Etre abonné'}]}
# {'null': [{'special': 'Etre abonné'}]}
# {'null': [{'special': 'Etre abonné'}]}
# {'null': [{'special': 'Etre abonné'}]}
# {'null': [{'special': 'Etre abonné'}]}
# {'null': [{'special': 'Etre abonné'}]}
# {'null': [{'special': 'Etre abonné'}]}
# {'null': [{'special': 'Etre abonné'}]}
# {'et': [{'special': 'Etre abonné'}, {'special': "Connaître l'attitude Salut Vulkain"}]}
# {'null': [{'special': 'Etre abonné'}]}
# {'null': [{'special': 'Etre abonné'}]}
# {'null': [{'special': 'Etre abonné'}]}
# {'et': [{'special': 'Alignement 2'}, {'>': ["Niveau d'alignement", 19]}]}
# {'null': [{'special': 'Etre abonné'}]}
# {'et': [{'special': 'Etre abonné'}, {'special': 'Alignement 2'}, {'>': ["Niveau d'alignement", 19]}]}
# {'et': [{'special': 'Etre abonné'}, {'special': 'Alignement 1'}, {'>': ["Niveau d'alignement", 19]}]}
# {'null': [{'special': 'Etre abonné'}]}
# {'et': [{'special': 'Alignement 1'}, {'>': ["Niveau d'alignement", 19]}]}
